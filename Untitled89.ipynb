# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnudorigundla/netflix-data/blob/main/Untitled89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("netflixData.csv")

# %%
data
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
data.tail()
# Out:
#                                    Show Id                Title  \
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d            الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6         دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                 海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26              반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# 5965  After people in his town start turning up dead...      Hong-seon Kim
# 5966  Miniforce, a special task force of elite range...      Young Jun Lee
#
#                                        Genres  \
# 5962   Comedies, Dramas, International Movies
# ...

# %%
data.shape
# Out:
# (5967, 13)

# %%
data.size
# Out:
# 77571

# %%
data.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Production Country', 'Release Date', 'Rating', 'Duration',
#        'Imdb Score', 'Content Type', 'Date Added'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show Id                object
# Title                  object
# Description            object
# Director               object
# Genres                 object
# Cast                   object
# Production Country     object
# Release Date          float64
# Rating                 object
# Duration               object
# Imdb Score             object
# Content Type           object
# Date Added             object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             5967 non-null   object
#  1   Title               5967 non-null   object
#  2   Description         5967 non-null   object
#  3   Director            3903 non-null   object
#  4   Genres              5967 non-null   object
#  5   Cast                5437 non-null   object
#  6   Production Country  5408 non-null   object
#  7   Release Date        5964 non-null   float64
#  8   Rating              5963 non-null   object
#  9   Duration            5964 non-null   object
#  10  Imdb Score          5359 non-null   object
#  11  Content Type        5967 non-null   object
#  12  Date Added          4632 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 606.1+ KB

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Length: 5967, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added]
# Index: []

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (5967, 13)

# %%
data.isnull()
# Out:
#       Show Id  Title  Description  Director  Genres   Cast  \
# 0       False  False        False      True   False   True
# 1       False  False        False     False   False  False
# 2       False  False        False     False   False  False
# 3       False  False        False      True   False  False
# 4       False  False        False     False   False   True
# ...       ...    ...          ...       ...     ...    ...
# 5962    False  False        False     False   False  False
# 5963    False  False        False      True   False  False
# 5964    False  False        False      True   False  False
# 5965    False  False        False     False   False  False
# 5966    False  False        False     False   False  False
#
#       Production Country  Release Date  Rating  Duration  Imdb Score  \
# 0                  False         False   False     False       False
# 1                  False         False   False     False       False
# ...

# %%
data.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
data['Title'].isin(['#Alive'])
# Out:
# 1        True
# 2       False
# 5       False
# 6       False
# 7       False
#         ...
# 5955    False
# 5957    False
# 5958    False
# 5962    False
# 5965    False
# Name: Title, Length: 3260, dtype: bool

# %%
data[data['Title'].isin(['#Alive'])]
# Out:
#                                 Show Id   Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb  #Alive
#
#                                          Description Director  \
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating Duration Imdb Score Content Type  \
# 1        South Korea        2020.0  TV-MA   99 min     6.2/10        Movie
#
#           Date Added
# 1  September 8, 2020

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3260 entries, 1 to 5965
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             3260 non-null   object
#  1   Title               3260 non-null   object
#  2   Description         3260 non-null   object
#  3   Director            3260 non-null   object
#  4   Genres              3260 non-null   object
#  5   Cast                3260 non-null   object
#  6   Production Country  3260 non-null   object
#  7   Release Date        3260 non-null   float64
#  8   Rating              3260 non-null   object
#  9   Duration            3260 non-null   object
#  10  Imdb Score          3260 non-null   object
#  11  Content Type        3260 non-null   object
#  12  Date Added          3260 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 485.6+ KB

# %%
data['Date']=pd.to_datetime(data['Date Added'])

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
data.dtypes
# Out:
# Show Id                       object
# Title                         object
# Description                   object
# Director                      object
# Genres                        object
# Cast                          object
# Production Country            object
# Release Date                 float64
# Rating                        object
# Duration                      object
# Imdb Score                    object
# Content Type                  object
# Date Added                    object
# Date                  datetime64[ns]
# dtype: object

# %%
## which year highest views
data['Date'].dt.year.value_counts()
# Out:
# Date
# 2020    952
# 2019    601
# 2018    597
# 2021    566
# 2017    353
# 2016    132
# 2015     31
# 2011     13
# 2014      8
# 2013      3
# 2009      2
# 2012      1
# 2008      1
# Name: count, dtype: int64

# %%
data['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
data.head(2)
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast Production Country  Release Date Rating  \
# 1     Yoo Ah-in, Park Shin-hye        South Korea        2020.0  TV-MA
# 2  Helen Mirren, Gengher Gatti              Italy        2019.0  TV-14
#
#   Duration Imdb Score Content Type         Date Added       Date
# ...

# %%
data['category'] = data['Content Type'].apply(lambda x: 'TV Shows' if x == 'TV Show' else 'Movies')

print(data)
# Out:
#                                    Show Id                          Title  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6     0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7     c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
# ...                                    ...                            ...
# 5955  ab343fbd-1064-405d-837c-8e99a2d0c543                            Zoo
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5                      Zoot Suit
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5                           Zozo
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
#
#                                             Description  \
# ...

# %%
data
# Out:
#                                    Show Id                          Title  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6     0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7     c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
# ...                                    ...                            ...
# 5955  ab343fbd-1064-405d-837c-8e99a2d0c543                            Zoo
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5                      Zoot Suit
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5                           Zozo
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
#
#                                             Description  \
# ...

# %%
data.groupby('category').category.count()
# Out:
# category
# Movies      3220
# TV Shows      40
# Name: category, dtype: int64

# %%
sns.countplot(data['category'])
# Out:
# <Axes: xlabel='count', ylabel='category'>

# %%
data.head(2)
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast Production Country  Release Date Rating  \
# 1     Yoo Ah-in, Park Shin-hye        South Korea        2020.0  TV-MA
# 2  Helen Mirren, Gengher Gatti              Italy        2019.0  TV-14
#
#   Duration Imdb Score Content Type         Date Added       Date category
# ...

# %%
data['year']=data['Date'].dt.year

# %%
data.head(2)
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast Production Country  Release Date Rating  \
# 1     Yoo Ah-in, Park Shin-hye        South Korea        2020.0  TV-MA
# 2  Helen Mirren, Gengher Gatti              Italy        2019.0  TV-14
#
#   Duration Imdb Score Content Type         Date Added       Date category  \
# ...

# %%
##filtering
data[(data['category']=='Movies') &(data['year']==2020)]
# Out:
#                                    Show Id                          Title  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6     0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 19    38055016-5475-41cc-af4b-a9610bacaa25                            122
# ...                                    ...                            ...
# 5922  46114921-1f62-481a-95ec-bc9bbd8e53ec      Your Name Engraved Herein
# 5925  57c553ed-5c34-4826-93e0-81ba4b6fcc7c    Yours Sincerely, Kanan Gill
# 5937  67575762-990e-4716-b6f8-7933f06a4cdd                      Zaki Chan
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5                           Zozo
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
#
#                                             Description  \
# ...

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
##show only titles of all Movies that were released in india
data[(data['category']=='Movies')&(data['Production Country']=='India')]
# Out:
#                                    Show Id                     Title  \
# 18    f5f2e34f-903d-4f77-9de5-31d8be73d305           1000 Rupee Note
# 24    4594bcbc-837f-497f-9eb9-02cc520e79ee                 15 August
# 32    79afe5bd-0dcd-4cac-9072-f77f46f355ef                  2 States
# 41    664d12b4-7ad8-4454-90c9-70586f70f7a5                  25 Kille
# 46    957847e1-57e0-4128-b6ed-2f422e5cb9b4                  3 Idiots
# ...                                    ...                       ...
# 5931  da62d57e-3770-47c1-bf92-0397c0992d90                      Yuva
# 5940  a0888ecb-b825-4e87-90e1-2fa104023e1d                      Zero
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e  Zindagi Na Milegi Dobara
# 5952  7d0102f5-dcca-4c1e-a75b-3641085ffe75                  Zokkomon
# 5955  ab343fbd-1064-405d-837c-8e99a2d0c543                       Zoo
#
#                                             Description  \
# 18    After randomly receiving a handsome political ...
# ...

# %%
data[(data['category']=='Movies')&(data['Production Country']=='India')]['Title']
# Out:
# 18               1000 Rupee Note
# 24                     15 August
# 32                      2 States
# 41                      25 Kille
# 46                      3 Idiots
#                   ...
# 5931                        Yuva
# 5940                        Zero
# 5947    Zindagi Na Milegi Dobara
# 5952                    Zokkomon
# 5955                         Zoo
# Name: Title, Length: 571, dtype: object

# %%
#top 0 directors
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Jay Karas                 14
# Marcus Raboy              14
# Cathy Garcia-Molina       12
# Youssef Chahine           12
# Jay Chapman               11
# Don Michael Paul           8
# Kunle Afolayan             7
# Yılmaz Erdoğan             7
# Johnnie To                 7
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
##filtering using and and or operator
data[(data['category']=='category')&(data['Genres']=='Comedies')|(data['Production Country']=='India')]
# Out:
#                                    Show Id                     Title  \
# 18    f5f2e34f-903d-4f77-9de5-31d8be73d305           1000 Rupee Note
# 24    4594bcbc-837f-497f-9eb9-02cc520e79ee                 15 August
# 32    79afe5bd-0dcd-4cac-9072-f77f46f355ef                  2 States
# 41    664d12b4-7ad8-4454-90c9-70586f70f7a5                  25 Kille
# 46    957847e1-57e0-4128-b6ed-2f422e5cb9b4                  3 Idiots
# ...                                    ...                       ...
# 5931  da62d57e-3770-47c1-bf92-0397c0992d90                      Yuva
# 5940  a0888ecb-b825-4e87-90e1-2fa104023e1d                      Zero
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e  Zindagi Na Milegi Dobara
# 5952  7d0102f5-dcca-4c1e-a75b-3641085ffe75                  Zokkomon
# 5955  ab343fbd-1064-405d-837c-8e99a2d0c543                       Zoo
#
#                                             Description  \
# 18    After randomly receiving a handsome political ...
# ...

# %%
data['Cast'].value_counts()
# Out:
# Cast
# Jeff Dunham                                                                                                                                                     7
# Jim Gaffigan                                                                                                                                                    5
# Jerry Seinfeld                                                                                                                                                  4
# Bill Hicks                                                                                                                                                      4
# Tom Segura                                                                                                                                                      4
#                                                                                                                                                                ..
# ...

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
##how many movis alia batt having
data[data['Cast']=='Jeff Dunham ']
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added, Date, category, year]
# Index: []

# %%
data[data['Cast'].str.contains('Jeff Dunham')]
# Out:
#                                    Show Id  \
# 1493  2e94252a-f912-4c48-b66d-006c3ff4894d
# 1841  6aee7fd2-fe43-40dc-9a07-68d7be0dd129
# 2343  987f3531-2a09-4fb5-8944-192c6c54d4b3
# 2344  bd7c90f9-1479-4bb1-b490-30b26e10eeec
# 2345  329fb4ce-fb48-4330-8640-92c47713c94a
# 2346  764c64d0-f798-4d86-8314-36caccf30aa4
# 2347  ed782db4-9053-4771-83ee-be7ecf638c06
# 2348  6bb920f8-2c50-4b1a-aaac-c64c676a142e
# 2349  b585ddd4-0595-43a3-9e31-278b17a80670
# 2350  7946d222-2527-4c2c-9e64-828dde44b637
# 5084  f88e0c87-a6c2-4567-96be-60502014b683
#
#                                              Title  \
# 1493                  Elliot the Littlest Reindeer
# 1841                                   Gnome Alone
# 2343                 Jeff Dunham: All Over the Map
# 2344              Jeff Dunham: Arguing with Myself
# 2345                   Jeff Dunham: Beside Himself
# 2346                 Jeff Dunham: Controlled Chaos
# 2347             Jeff Dunham: Minding the Monsters
# ...

# %%
data_new=data.dropna()

# %%
data_new.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
data[data['Cast']==' Jeff Dunham']
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added, Date, category, year]
# Index: []

# %%
data['Rating'].nunique()
# Out:
# 11

# %%
data['Rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'TV-G', 'R', 'PG-13', 'TV-PG', 'PG', 'TV-Y7',
#        'TV-Y', 'G', 'NC-17'], dtype=object)

# %%
data[(data['category']=='Movies')&(data['Rating']=='TV-14')]
# Out:
#                                    Show Id                          Title  \
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 7     c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
# 11    ea94d1e2-dfb5-4fb0-b941-ca4b1ade98c1            10 Days in Sun City
# 12    eb2818f5-d01b-46fe-8797-931a767d5831                 10 jours en or
# 17    541d3749-9908-4eae-acf0-8dcb68aa76df                     100% Halal
# ...                                    ...                            ...
# 5931  da62d57e-3770-47c1-bf92-0397c0992d90                           Yuva
# 5940  a0888ecb-b825-4e87-90e1-2fa104023e1d                           Zero
# 5946  29d0e27f-3382-44c9-82fe-8768f5dd127c       Zindagi Kitni Haseen Hay
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e       Zindagi Na Milegi Dobara
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
#
#                                             Description  \
# ...

# %%
data[(data['category']=='Movies')&(data['Rating']=='TV-14')&(data['year']>2018)]
# Out:
#                                    Show Id                          Title  \
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 11    ea94d1e2-dfb5-4fb0-b941-ca4b1ade98c1            10 Days in Sun City
# 17    541d3749-9908-4eae-acf0-8dcb68aa76df                     100% Halal
# 24    4594bcbc-837f-497f-9eb9-02cc520e79ee                      15 August
# 53    eeeeec93-6de4-4a3f-8722-2de81adb7ca6                      40 Sticks
# ...                                    ...                            ...
# 5884  f5022ca7-5c2c-4adc-a0df-8db0a467d98f                        X Large
# 5913  5bbf1ee3-d275-4250-afba-4ea8ab3877fa                 You're My Boss
# 5940  a0888ecb-b825-4e87-90e1-2fa104023e1d                           Zero
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e       Zindagi Na Milegi Dobara
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
#
#                                             Description  \
# ...

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 5  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 6  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
# 7  c844460f-6178-4f87-929e-80816c74ca35                   #realityhigh
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 5  Pining for his high school crush for years, a ...
# 6  As Ayu and Ditto finally transition from best ...
# 7  When nerdy high schooler Dani finally attracts...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 5                Rako Prijanto
# 6                Rako Prijanto
# 7             Fernando Lebrija
#
# ...

# %%
data.Duration.nunique()
# Out:
# 182

# %%
data.Duration.unique()
# Out:
# array(['99 min', '95 min', '102 min', '104 min', '125 min', '119 min',
#        '87 min', '97 min', '109 min', '101 min', '89 min', '124 min',
#        '114 min', '130 min', '103 min', '90 min', '143 min', '158 min',
#        '144 min', '78 min', '140 min', '135 min', '117 min', '92 min',
#        '164 min', '93 min', '91 min', '116 min', '84 min', '105 min',
#        '96 min', '75 min', '115 min', '129 min', '80 min', '77 min',
#        '148 min', '123 min', '121 min', '131 min', '122 min', '107 min',
#        '94 min', '85 min', '22 min', '86 min', '137 min', '68 min',
#        '29 min', '168 min', '59 min', '113 min', '108 min', '111 min',
#        '110 min', '100 min', '26 min', '156 min', '57 min', '98 min',
#        '133 min', '154 min', '146 min', '136 min', '106 min', '88 min',
#        '52 min', '24 min', '74 min', '63 min', '120 min', '151 min',
#        '174 min', '60 min', '81 min', '150 min', '142 min', '162 min',
# ...

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data[['minutes','units']]=data['Duration'].str.split(' ',expand=True)

# %%
data.head(2)
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast Production Country  Release Date Rating  \
# 1     Yoo Ah-in, Park Shin-hye        South Korea        2020.0  TV-MA
# 2  Helen Mirren, Gengher Gatti              Italy        2019.0  TV-14
#
#   Duration Imdb Score Content Type         Date Added       Date category  \
# ...

# %%
data['minutes']
# Out:
# 1        99
# 2        95
# 5       102
# 6       104
# 7        99
#        ...
# 5955     94
# 5957    103
# 5958     99
# 5962    115
# 5965    110
# Name: minutes, Length: 3260, dtype: object

# %%
data['minutes'].max()
# Out:
# '99'

# %%
data.tail(30)
# Out:
#                                    Show Id  \
# 5906  f059feff-214d-4e37-b654-f57524e3d815
# 5907  0cc6c39f-4670-4b84-928d-2c554a684293
# 5910  77ae5c86-acef-40fd-b0fc-b0720bb7644f
# 5912  3f991baf-6450-4d5d-bbef-3342672b1445
# 5913  5bbf1ee3-d275-4250-afba-4ea8ab3877fa
# 5915  3c2221cf-6a43-4847-b022-cc2c35cb4c24
# 5920  17555cab-dea0-4561-9622-d7a57532e873
# 5922  46114921-1f62-481a-95ec-bc9bbd8e53ec
# 5923  4d63b322-3b30-4b77-ab97-c27010b9229c
# 5925  57c553ed-5c34-4826-93e0-81ba4b6fcc7c
# 5928  35275217-7609-4fc7-91ad-cf0dd8246ec0
# 5931  da62d57e-3770-47c1-bf92-0397c0992d90
# 5935  98ef8f45-c08e-4a87-82f0-2b8994effb06
# 5936  789cd896-50c8-4145-8011-a4a321007003
# 5937  67575762-990e-4716-b6f8-7933f06a4cdd
# 5938  96075775-3b09-4fa2-8330-038efc7695fa
# 5939  b987ef8b-4453-4780-9268-e0cb56998e7f
# 5940  a0888ecb-b825-4e87-90e1-2fa104023e1d
# 5946  29d0e27f-3382-44c9-82fe-8768f5dd127c
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e
# 5948  a86a960f-52e3-4e7c-8c1e-0f878d49814f
# ...

# %%
data1=data[data['category']=='TV Shows']

# %%
data1.head(2)
# Out:
#                                   Show Id             Title  \
# 418  9df572ba-f875-4ba9-b624-e3fe9c4e684a             Arrow
# 867  04d6f585-66ae-43f1-b788-e74385295d3a  Call the Midwife
#
#                                            Description            Director  \
# 418  Based on DC Comics' Green Arrow, an affluent p...       James Bamford
# 867  This period drama set in impoverished East Lon...  Philippa Lowthorpe
#
#                                                 Genres  \
# 418              Crime TV Shows, TV Action & Adventure
# 867  British TV Shows, International TV Shows, TV D...
#
#                                                   Cast Production Country  \
# 418  Stephen Amell, Katie Cassidy, David Ramsey, Wi...      United States
# 867  Vanessa Redgrave, Bryony Hannah, Helen George,...     United Kingdom
#
#      Release Date Rating   Duration Imdb Score Content Type  \
# 418        2019.0  TV-14  8 Seasons     7.6/10      TV Show
# ...

# %%
data1.rename(columns={'Production Country': 'country'}, inplace=True)
# Out:
# <ipython-input-135-81ae477b0ee6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.rename(columns={'Production Country': 'country'}, inplace=True)

# %%
data1.head()
# Out:
#                                    Show Id                             Title  \
# 418   9df572ba-f875-4ba9-b624-e3fe9c4e684a                             Arrow
# 867   04d6f585-66ae-43f1-b788-e74385295d3a                  Call the Midwife
# 1075  6514ada3-6e16-413d-8b4f-dae4b8474406  Comedians in Cars Getting Coffee
# 1220  74439e0c-4051-4ccc-8343-4ccd147c0f03          DC's Legends of Tomorrow
# 1251  e7f06254-8920-4569-9eeb-175c23740e2e              Degrassi: Next Class
#
#                                             Description            Director  \
# 418   Based on DC Comics' Green Arrow, an affluent p...       James Bamford
# 867   This period drama set in impoverished East Lon...  Philippa Lowthorpe
# 1075  Jerry Seinfeld's roving talk show combines cof...      Jerry Seinfeld
# 1220  A mysterious "time master" from the future uni...     Rob Seidenglanz
# 1251  Degrassi's next generation of high-tech newbie...      Stefan Brogren
#
# ...

# %%
data1.new_name1.value_counts()
# Out:
# new_name1
# United States                                               10
# United Kingdom                                               9
# Japan                                                        4
# Canada                                                       2
# Spain                                                        2
# United States, Canada                                        1
# Thailand                                                     1
# Poland                                                       1
# Brazil                                                       1
# Canada, United Kingdom, United States                        1
# India, United States                                         1
# China                                                        1
# France, South Korea, Japan, Spain, Mexico, United States     1
# South Korea                                                  1
# Turkey                                                       1
# ...

# %%
data1['new_name1'].value_counts()
# Out:
# new_name1
# United States                                               10
# United Kingdom                                               9
# Japan                                                        4
# Canada                                                       2
# Spain                                                        2
# United States, Canada                                        1
# Thailand                                                     1
# Poland                                                       1
# Brazil                                                       1
# Canada, United Kingdom, United States                        1
# India, United States                                         1
# China                                                        1
# France, South Korea, Japan, Spain, Mexico, United States     1
# South Korea                                                  1
# Turkey                                                       1
# ...

# %%
data1.sort_values(by='year').head(10)
# Out:
#                                    Show Id                             Title  \
# 2023  7d0045a4-90ea-4cc9-a07a-abfb40b5a3d9                     Hemlock Grove
# 3045  67c92a53-c49f-4bd2-847a-fd9b3f0ae4f4                            Merlin
# 2593  c78f27d7-9ee2-479e-9772-82de8b178aa4                        Kuromukuro
# 5873  ba96339e-eb78-4c2a-893f-ff3c52eb79de                     World of Winx
# 2701  faecb7ec-9844-4a27-be14-9fdcacb5edfc                  Leyla and Mecnun
# 1251  e7f06254-8920-4569-9eeb-175c23740e2e              Degrassi: Next Class
# 5416  14f7bb91-036d-45cd-a7ce-2948e5a54625                   Toast of London
# 2077  befdc6ec-da01-4b03-82d2-b88fc68bf6cb                   Hoff the Record
# 1838  f7f60dac-3e68-4f8f-a23c-34dfddc5fa7e           Glitter Force Doki Doki
# 1738  f04b1850-e6fc-4b74-99d9-cedfa75d8532  Fullmetal Alchemist: Brotherhood
#
#                                             Description         Director  \
# ...

# %%
sns.barplot(data1)
# Out:
# <Axes: >

# %%
sns.boxplot(data1)
# Out:
# <Axes: >

# %%
sns.histplot(data1)
# Out:
# <Axes: ylabel='Count'>
